# %%
#pydoe, diverspy and doepy libraries needed!

from doepy import build
from doepy import read_write

# %%
params = build.space_filling_lhs(
{'BRS_capacity':[10,12,14,16,18,20,22,24,26],
'BRS_energyconent':[2000, 3000, 4000],
'fix_bat_size':[30000,40000,50000]},
num_samples = 12
)

params
# Out:
# BRS_capacity had more than two levels. Assigning the end point to the high level.
# BRS_energyconent had more than two levels. Assigning the end point to the high level.
# fix_bat_size had more than two levels. Assigning the end point to the high level.
#     BRS_capacity  BRS_energyconent  fix_bat_size
# 0      11.454545       2363.636364  35454.545455
# 1      17.272727       2181.818182  40909.090909
# 2      20.181818       2000.000000  46363.636364
# 3      14.363636       3454.545455  48181.818182
# 4      24.545455       2909.090909  30000.000000
# 5      23.090909       3090.909091  42727.272727
# 6      10.000000       3818.181818  31818.181818
# 7      18.727273       2727.272727  39090.909091
# 8      21.636364       2545.454545  50000.000000
# 9      15.818182       3272.727273  44545.454545
# 10     26.000000       3636.363636  37272.727273
# 11     12.909091       4000.000000  33636.363636

# %%
read_write.write_csv(
params,
filename='DOE_table.csv'
)
